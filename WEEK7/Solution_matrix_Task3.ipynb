# %% [markdown]
# Considering the problem Given
# A = ([[2, -1],
#         [0, 3]])
#
# B = ([[1, 4],
#         [-2, 5]])
#
# with scalar of
# c = 2
#
# D = 3
#
#
# Solving the following using  (cA),(dB),and (c + d)A
# These following are our working function
#
# cA = 2 ([[2, -1],
#         [0, 3]])
#
# cA = ([[4, -2]
#        [0, 6]])
#
# dB = 3 ([[1, 4],
#         [-2, 5]])
#
# dB = ([[3, 12],
#        [-6, 15]])
#
# (c+d) A = 5 ([[2, -1],
#              [0, 3]])
#
# (c+d) A = ([[10, -5]
#             [0, 15]])
#
#
# (1) Asssociativity of Scalar Multiplication
#
# (c.d)A = c.(dA)
# (c.d) = 6
#
# (c.d)A = 6([[2, -1],
#             [0, -3]])
#
# (c.d)A = ([[12, -6]
#             [0, -18]])
#
# (dA) = 3([[2, -1],
#            [0, -3]])
#
# (dA) = ([[6, -3]
#         [0, -9]])
#
# c.(dA) = 2([[6, -3]
#             [0, -9]])
#
# c.(dA) = ([[12, -6],
#            [0, -18]])
#
#
# (2) Distributivity over Matrix addition
#
# c(A + B) = cA + cB
# A = ([[2, -1],
#      [0, 3]])
#
# B = ([[1, 4],
#      [-2, 5]])
#
# (A + B) = ([[2+1, -1+4],
#             [0+-2, 3+5]])
#
# (A + B) = ([[3, 3],
#             [-2, 8]])
#
# c(A + B) = 2([[3, 3],
#              [-2, 8]])
#
# c(A + B) = ([[6, 6],
#              [-4, 16]])
#
# cA = 2([[2, -1],
#         [0, 3]])
#
# cA = ([[4, -2],
#        [0, 6]])
#
# cB = 2([[1, 4],
#        [-2, 5]])
#
# cB = ([[2, 8],
#        [-4, 10]])
#
# cA + cB = ([[6, 6],
#            [-4, 16]])
#
#
# (3) Distributivity over scalar addition
#
# (c + d)A = cA + dA
# (c + d) = 2 + 3 = 5
#
# (c + d)A = 5([[2, -1],
#               [0, 3]])
#
# (c + d)A = ([[10, -5],
#             [0, 15]])
#
# cA = 2([[2, -1],
#         [0, 3]])
#
# cA = ([[4, -2],
#        [0, 6]])
#
# dA = 3([[2, -1],
#         [0, 3]])
#
# dA = ([[6, -3],
#        [0, 9]])
#
# cA + dA = ([[4+6, -2+-3],
#             [0+0, 6+9]])
#
# cA + dA = ([[10, -5],
#             [0, 15]])
#
#
# (4) Transpose of Matrix A
#
# A = ([[2, -1],
#      [0, 3]])
#
# AT = ([[2, 0],
#       [-1, 3]])
#
# B = ([[1, 4],
#      [-2, 5]])
#
# BT = ([[1, -2],
#      [4, 5]])

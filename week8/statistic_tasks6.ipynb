# %% [markdown]
# # Question 1
#
# #1a
# To calculate Mean
# We Sum  all the = 5+8+10+12+12+2+13+14+14+15+16+18+18+20+20
# Total = 207
#
# Recall that Number of scores  as stated in the question says = 15
# We need the divide total/15
# 207/15
# 13.8
#
#
#
# #2. Median
# Median  is known as Middle value after  scores are arranged in order.
# Before the arrangement : ( 5, 8, 10, 12, 12, 12, 13, 14, 14, 15, 16, 18, 18, 20, 20)
# Order : ( 5, 8, 10, 12, 12, 12, 13, 14, 14, 15, 16, 18, 18, 20, 20)
#
# So the Median = 14 ( 14 is at the center after 7 values on the left and right respectively)
#
#
# #3. Mode
# Mode as stated is the most frequent value (score).
# 12 appears 3 times.
# All others appear fewer times.
# So, Mode = 12
#
#
#
# # Question 1b
# # Mean
#
# If the lowest score (5) was wrongly recorded and should have been 10
# It means we will replace the value 5 with 10 i.e
#
#  10, 8, 10, 12, 12, 12, 13, 14, 14, 15, 16, 18, 18, 20, 20
# So let's arrange now:
#  8, 10, 10, 12, 12, 12, 13, 14, 14, 15, 16, 18, 18, 20, 20
#
#  New Sum =212
#  Which now be:      212 /15
# 	New Mean	: 14.13
#
# # Median
# Then the new median will now (8, 10, 10, 12, 12, 12, 13, 14, 14, 15, 16, 18, 18, 20, 20)
# 14 is still at center
# Still 15 numbers  at the center as 8th value = 14
# Meaning  median unchange at all =14
#
# # Mode:
# 12 still appears 3 times.
# (8, 10, 10, 12, 12, 12, 13, 14, 14, 15, 16, 18, 18, 20, 20)
# So Mode is still 12.
#
#
# # Question 2: Daily Commute Times
#
# # Mean
# Values : A group of 9 students reported the time (in minutes) it takes them to get to school each day: (15, 20, 20, 25, 25, 30, 60, 65, 120)
#
# # So let’s add all scores values after arranging them
#
# =  15+20+20+25+25+30+60+65+120
# Total =  380/9
# Mean:	42.22( Minutes)
#
# # Median
#
#  The values are : 15, 20, 20, 25, 25, 30, 60, 65, 120
# We solve by counting to the left and right 4 values and (25) is at the center
#
# Meaning median is 25
#
# # Mode now:
# SCORE VALUES : 15, 20, 20, 25, 25, 30, 60, 65, 120
#
# 20, 25 appears more than other scores twice
# I.e 20 & 25 is the Mode
# Meaning mode in this case is = Bimodal
#
#
#
# # Question3
# The shoe sizes of students in a class are:
# 38, 39, 38, 40, 41, 42, 39, 39, 40, 38, 37, 39, 40, 41, 42
#
# # Mean
#
# Firstly we do the normal thing by rearrange the values in order
#       37+38+38+38+39+39+39+39+40+40+40+41+41+42+42
# Now
#      	Sum of all sizes/ Number of students in class which 15(started in the question)​
# 	37+38+38+38+39+39+39+39+40+40+40+41+41+42+42 = 593
# To calculate Mean     593/15
# 			39.53
# # Median:
# 	37+38+38+38+39+39+39+39+40+40+40+41+41+42+42
# The center value number is : 39 is on the center after counting 7 values scores on both side
#      Median  is 39
#
# # Mode:
#
# To calculate mode : (37+38+38+38+39+39+39+39+40+40+40+41+41+42+42)
#  We check out the scores that come-up more than one:
# Which is 39 ( The number came up 4 times in the value)
#
# # Q 3b : If a shoe company wants to donate free shoes, which size should they produce most of? Why?
#
# The size 39 is the most performing shoes with students. So, therefore, the most producing size for the company should be 39 size because it appears 4 times.
#
# # Q3c. What if they only want to produce one size that would fit the "average" student? Should they use mean, median, or mode? Defend your answer.
#
#
# Mode (39) is most considerably used shoe size by the students and is  to be produced if the company wants to gain profit and not loosing money to wastage which is size 39.
